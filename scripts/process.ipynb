# %%
import sys
import json
import re
from tabulate import tabulate

# %%
profile_file = "bash_syscalls.profile"

# %%
with open(profile_file) as f:
    list_stats = f.read().split(',')
    fields = ["count", "native", "virtual"]
    feats = [dict(zip(fields, [int(x) for x in re.search("(\d*):(\d*)/(\d*)", elem).groups()])) for elem in list_stats]
    with open("syscall_list.txt") as g:
        syscall_list = g.read().split('\n')
        final_dict = dict(zip(syscall_list, feats))
        for k, v in final_dict.items():
            final_dict[k]["overhead"] = ((v["virtual"] / v["native"])-1)*100 if v["native"] else 0

# %%
#for k, v in final_dict.items():
print ("{:<20} {:<10} {:<15} {:<15} {:<10}".format('Syscall', 'Count', 'Native (ns)', 'Virtual (ns)', 'Overhead (%)'))
for k, v in sorted(final_dict.items(), key=lambda x: x[1]["overhead"], reverse=True):
    print ("{:<20} {:<10} {:<15} {:<15} {:<10}".format(k, v["count"], v["native"], v["virtual"], v["overhead"]))
# Out:
# Syscall              Count      Native (ns)     Virtual (ns)    Overhead (%)
# rt_sigaction         81         180             327             81.66666666666667
# set_tid_address      1          201             284             41.29353233830846
# geteuid              1          112             157             40.178571428571416
# getegid              1          111             155             39.63963963963963
# getpid               4          98              130             32.65306122448979
# getgid               1          128             169             32.03125
# getuid               1          145             190             31.034482758620683
# dup2                 1          167             213             27.544910179640713
# clock_gettime        684        145             174             19.999999999999996
# getppid              3          168             201             19.64285714285714
# dup                  1          193             230             19.17098445595855
# prlimit64            2          180             213             18.333333333333336
# getpgid              2          293             345             17.74744027303754
# fcntl                15         171             201             17.543859649122815
# fstat                7          348             388             11.494252873563227
# lseek                1          456             508             11.403508771929815
# writev               463        1046            1144            9.369024856596564
# setpgid              1          681             739             8.516886930983848
# uname                1          511             551             7.8277886497064575
# mmap                 78         986             1060            7.5050709939147975
# chdir                2          422             453             7.345971563981046
# rt_sigprocmask       38         509             544             6.876227897838905
# lstat                8          576             607             5.381944444444442
# munmap               40         1209            1270            5.045492142266328
# ioctl                30         669             702             4.932735426008961
# access               1          1300            1349            3.769230769230769
# close                19         939             974             3.727369542066028
# mprotect             2          1527            1575            3.143418467583503
# stat                 54         1086            1120            3.130755064456725
# read                 22         2311            2373            2.682821289485071
# open                 20         1322            1353            2.344931921331317
# pipe                 1          7578            7638            0.7917656373713333
# fork                 2          233468          234976          0.6459129302516908
# getdents64           9          6438            6467            0.45045045045044585
# wait4                4          402668          402724          0.013907238717747461
# pselect6             20         127692066       127692228       0.00012686771000414154
# write                0          0               0               0
# poll                 0          0               0               0
# brk                  0          0               0               0
# rt_sigreturn         0          0               0               0
# pread64              0          0               0               0
# pwrite64             0          0               0               0
# readv                0          0               0               0
# select               0          0               0               0
# sched_yield          0          0               0               0
# mremap               0          0               0               0
# msync                0          0               0               0
# mincore              0          0               0               0
# madvise              0          0               0               0
# shmget               0          0               0               0
# shmat                0          0               0               0
# shmctl               0          0               0               0
# pause                0          0               0               0
# nanosleep            0          0               0               0
# getitimer            0          0               0               0
# alarm                0          0               0               0
# setitimer            0          0               0               0
# sendfile             0          0               0               0
# socket               0          0               0               0
# connect              0          0               0               0
# accept               0          0               0               0
# sendto               0          0               0               0
# recvfrom             0          0               0               0
# sendmsg              0          0               0               0
# recvmsg              0          0               0               0
# shutdown             0          0               0               0
# bind                 0          0               0               0
# listen               0          0               0               0
# getsockname          0          0               0               0
# getpeername          0          0               0               0
# socketpair           0          0               0               0
# setsockopt           0          0               0               0
# getsockopt           0          0               0               0
# clone                0          0               0               0
# vfork                0          0               0               0
# execve               0          0               0               0
# exit                 0          0               0               0
# kill                 0          0               0               0
# semget               0          0               0               0
# semop                0          0               0               0
# semctl               0          0               0               0
# shmdt                0          0               0               0
# msgget               0          0               0               0
# msgsnd               0          0               0               0
# msgrcv               0          0               0               0
# msgctl               0          0               0               0
# flock                0          0               0               0
# fsync                0          0               0               0
# fdatasync            0          0               0               0
# truncate             0          0               0               0
# ftruncate            0          0               0               0
# getdents             0          0               0               0
# getcwd               0          0               0               0
# fchdir               0          0               0               0
# rename               0          0               0               0
# mkdir                0          0               0               0
# rmdir                0          0               0               0
# creat                0          0               0               0
# link                 0          0               0               0
# unlink               0          0               0               0
# symlink              0          0               0               0
# readlink             0          0               0               0
# chmod                0          0               0               0
# fchmod               0          0               0               0
# chown                0          0               0               0
# fchown               0          0               0               0
# lchown               0          0               0               0
# umask                0          0               0               0
# gettimeofday         0          0               0               0
# getrlimit            0          0               0               0
# getrusage            0          0               0               0
# sysinfo              0          0               0               0
# times                0          0               0               0
# ptrace               0          0               0               0
# syslog               0          0               0               0
# setuid               0          0               0               0
# setgid               0          0               0               0
# getpgrp              0          0               0               0
# setsid               0          0               0               0
# setreuid             0          0               0               0
# setregid             0          0               0               0
# getgroups            0          0               0               0
# setgroups            0          0               0               0
# setresuid            0          0               0               0
# getresuid            0          0               0               0
# setresgid            0          0               0               0
# getresgid            0          0               0               0
# setfsuid             0          0               0               0
# setfsgid             0          0               0               0
# getsid               0          0               0               0
# capget               0          0               0               0
# capset               0          0               0               0
# rt_sigpending        0          0               0               0
# rt_sigtimedwait      0          0               0               0
# rt_sigqueueinfo      0          0               0               0
# rt_sigsuspend        0          0               0               0
# sigaltstack          0          0               0               0
# utime                0          0               0               0
# mknod                0          0               0               0
# uselib               0          0               0               0
# personality          0          0               0               0
# ustat                0          0               0               0
# statfs               0          0               0               0
# fstatfs              0          0               0               0
# sysfs                0          0               0               0
# getpriority          0          0               0               0
# setpriority          0          0               0               0
# sched_setparam       0          0               0               0
# sched_getparam       0          0               0               0
# sched_setscheduler   0          0               0               0
# sched_getscheduler   0          0               0               0
# sched_get_priority_max 0          0               0               0
# sched_get_priority_min 0          0               0               0
# sched_rr_get_interval 0          0               0               0
# mlock                0          0               0               0
# munlock              0          0               0               0
# mlockall             0          0               0               0
# munlockall           0          0               0               0
# vhangup              0          0               0               0
# modify_ldt           0          0               0               0
# pivot_root           0          0               0               0
# _sysctl              0          0               0               0
# prctl                0          0               0               0
# arch_prctl           0          0               0               0
# adjtimex             0          0               0               0
# setrlimit            0          0               0               0
# chroot               0          0               0               0
# sync                 0          0               0               0
# acct                 0          0               0               0
# settimeofday         0          0               0               0
# mount                0          0               0               0
# umount2              0          0               0               0
# swapon               0          0               0               0
# swapoff              0          0               0               0
# reboot               0          0               0               0
# sethostname          0          0               0               0
# setdomainname        0          0               0               0
# iopl                 0          0               0               0
# ioperm               0          0               0               0
# create_module        0          0               0               0
# init_module          0          0               0               0
# delete_module        0          0               0               0
# get_kernel_syms      0          0               0               0
# query_module         0          0               0               0
# quotactl             0          0               0               0
# nfsservctl           0          0               0               0
# getpmsg              0          0               0               0
# putpmsg              0          0               0               0
# afs_syscall          0          0               0               0
# tuxcall              0          0               0               0
# security             0          0               0               0
# gettid               0          0               0               0
# readahead            0          0               0               0
# setxattr             0          0               0               0
# lsetxattr            0          0               0               0
# fsetxattr            0          0               0               0
# getxattr             0          0               0               0
# lgetxattr            0          0               0               0
# fgetxattr            0          0               0               0
# listxattr            0          0               0               0
# llistxattr           0          0               0               0
# flistxattr           0          0               0               0
# removexattr          0          0               0               0
# lremovexattr         0          0               0               0
# fremovexattr         0          0               0               0
# tkill                0          0               0               0
# time                 0          0               0               0
# futex                0          0               0               0
# sched_setaffinity    0          0               0               0
# sched_getaffinity    0          0               0               0
# set_thread_area      0          0               0               0
# io_setup             0          0               0               0
# io_destroy           0          0               0               0
# io_getevents         0          0               0               0
# io_submit            0          0               0               0
# io_cancel            0          0               0               0
# get_thread_area      0          0               0               0
# lookup_dcookie       0          0               0               0
# epoll_create         0          0               0               0
# epoll_ctl_old        0          0               0               0
# epoll_wait_old       0          0               0               0
# remap_file_pages     0          0               0               0
# restart_syscall      0          0               0               0
# semtimedop           0          0               0               0
# fadvise64            0          0               0               0
# timer_create         0          0               0               0
# timer_settime        0          0               0               0
# timer_gettime        0          0               0               0
# timer_getoverrun     0          0               0               0
# timer_delete         0          0               0               0
# clock_settime        0          0               0               0
# clock_getres         0          0               0               0
# clock_nanosleep      0          0               0               0
# exit_group           0          0               0               0
# epoll_wait           0          0               0               0
# epoll_ctl            0          0               0               0
# tgkill               0          0               0               0
# utimes               0          0               0               0
# vserver              0          0               0               0
# mbind                0          0               0               0
# set_mempolicy        0          0               0               0
# get_mempolicy        0          0               0               0
# mq_open              0          0               0               0
# mq_unlink            0          0               0               0
# mq_timedsend         0          0               0               0
# mq_timedreceive      0          0               0               0
# mq_notify            0          0               0               0
# mq_getsetattr        0          0               0               0
# kexec_load           0          0               0               0
# waitid               0          0               0               0
# add_key              0          0               0               0
# request_key          0          0               0               0
# keyctl               0          0               0               0
# ioprio_set           0          0               0               0
# ioprio_get           0          0               0               0
# inotify_init         0          0               0               0
# inotify_add_watch    0          0               0               0
# inotify_rm_watch     0          0               0               0
# migrate_pages        0          0               0               0
# openat               0          0               0               0
# mkdirat              0          0               0               0
# mknodat              0          0               0               0
# fchownat             0          0               0               0
# futimesat            0          0               0               0
# newfstatat           0          0               0               0
# unlinkat             0          0               0               0
# renameat             0          0               0               0
# linkat               0          0               0               0
# symlinkat            0          0               0               0
# readlinkat           0          0               0               0
# fchmodat             0          0               0               0
# faccessat            0          0               0               0
# ppoll                0          0               0               0
# unshare              0          0               0               0
# set_robust_list      0          0               0               0
# get_robust_list      0          0               0               0
# splice               0          0               0               0
# tee                  0          0               0               0
# sync_file_range      0          0               0               0
# vmsplice             0          0               0               0
# move_pages           0          0               0               0
# utimensat            0          0               0               0
# epoll_pwait          0          0               0               0
# signalfd             0          0               0               0
# timerfd_create       0          0               0               0
# eventfd              0          0               0               0
# fallocate            0          0               0               0
# timerfd_settime      0          0               0               0
# timerfd_gettime      0          0               0               0
# accept4              0          0               0               0
# signalfd4            0          0               0               0
# eventfd2             0          0               0               0
# epoll_create1        0          0               0               0
# dup3                 0          0               0               0
# pipe2                0          0               0               0
# inotify_init1        0          0               0               0
# preadv               0          0               0               0
# pwritev              0          0               0               0
# rt_tgsigqueueinfo    0          0               0               0
# perf_event_open      0          0               0               0
# recvmmsg             0          0               0               0
# fanotify_init        0          0               0               0
# fanotify_mark        0          0               0               0
# name_to_handle_at    0          0               0               0
# open_by_handle_at    0          0               0               0
# clock_adjtime        0          0               0               0
# syncfs               0          0               0               0
# sendmmsg             0          0               0               0
# setns                0          0               0               0
# getcpu               0          0               0               0
# process_vm_readv     0          0               0               0
# process_vm_writev    0          0               0               0
# kcmp                 0          0               0               0
# finit_module         0          0               0               0
# sched_setattr        0          0               0               0
# sched_getattr        0          0               0               0
# renameat2            0          0               0               0
# seccomp              0          0               0               0
# getrandom            0          0               0               0
# memfd_create         0          0               0               0
# kexec_file_load      0          0               0               0
# bpf                  0          0               0               0
# execveat             0          0               0               0
# userfaultfd          0          0               0               0
# membarrier           0          0               0               0
# mlock2               0          0               0               0
# copy_file_range      0          0               0               0
# preadv2              0          0               0               0
# pwritev2             0          0               0               0
# pkey_mprotect        0          0               0               0
# pkey_alloc           0          0               0               0
# pkey_free            0          0               0               0
# statx                0          0               0               0
# io_pgetevents        0          0               0               0
# rseq                 0          0               0               0
# pidfd_send_signal    0          0               0               0
# io_uring_setup       0          0               0               0
# io_uring_enter       0          0               0               0
# io_uring_register    0          0               0               0
# open_tree            0          0               0               0
# move_mount           0          0               0               0
# fsopen               0          0               0               0
# fsconfig             0          0               0               0
# fsmount              0          0               0               0
# fspick               0          0               0               0
# pidfd_open           0          0               0               0
# clone3               0          0               0               0
# close_range          0          0               0               0
# openat2              0          0               0               0
# pidfd_getfd          0          0               0               0
# faccessat2           0          0               0               0
# process_madvise      0          0               0               0
# epoll_pwait2         0          0               0               0
# mount_setattr        0          0               0               0
# landlock_create_ruleset 0          0               0               0
# landlock_add_rule    0          0               0               0
# landlock_restrict_self 0          0               0               0
#                      0          0               0               0

# %%
print(final_dict["fork"])
# Out:
# {'count': 2, 'native': 233468, 'virtual': 234976, 'overhead': 0.6459129302516908}
